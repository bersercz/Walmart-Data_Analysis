# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Dell\Desktop\SQL-Projects\Projects\Project_7\Walmart.csv')

# %%
data
# Out:
#        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
data.shape
# Out:
# (10051, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10051 entries, 0 to 10050
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_id      10051 non-null  int64
#  1   Branch          10051 non-null  object
#  2   City            10051 non-null  object
#  3   category        10051 non-null  object
#  4   unit_price      10020 non-null  object
#  5   quantity        10020 non-null  float64
#  6   date            10051 non-null  object
#  7   time            10051 non-null  object
#  8   payment_method  10051 non-null  object
#  9   rating          10051 non-null  float64
#  10  profit_margin   10051 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 863.9+ KB

# %%
data.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000

# %%
data.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
#        invoice_id   Branch         City             category unit_price  \
# 10000        9950  WALM038   Sugar Land  Fashion accessories        $17
# 10001        9951  WALM082      Weslaco   Home and lifestyle        $58
# 10002        9952  WALM035   San Angelo  Fashion accessories        $76
# 10003        9953  WALM084      Schertz   Home and lifestyle        $68
# 10004        9954  WALM046       Temple  Fashion accessories        $40
# 10005        9955  WALM054      Sherman   Home and lifestyle        $61
# 10006        9956  WALM003  San Antonio  Fashion accessories        $17
# 10007        9957  WALM029   Round Rock   Home and lifestyle        $53
# 10008        9958  WALM084      Schertz  Fashion accessories        $35
# 10009        9959  WALM065   Texas City   Home and lifestyle        $36
# 10010        9960  WALM054      Sherman  Fashion accessories        $42
# 10011        9961  WALM046       Temple   Home and lifestyle        $70
# ...

# %%
data.drop_duplicates(keep = 'first', inplace = True)
data.shape
# Out:
# (10000, 11)

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (9969, 11)

# %%
data['unit_price'] = data['unit_price'].str.replace('$', '' ).astype(float)

# %%
data.unit_price.dtype
# Out:
# dtype('float64')

# %%
data['total'] = data['unit_price'] * data['quantity']

# %%
# !pip install psycopg2 sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 599.9 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 599.9 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 599.9 kB/s eta 0:00:03
#    --------- ------------------------------ 0.5/2.1 MB 599.9 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.1 MB 414.5 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 414.5 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.1 MB 414.5 kB/s eta 0:00:04
# ...

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
engine_psql = create_engine("postgresql+psycopg2://postgres:devansh123@localhost:5432/Project_7")
try:
    engine_psql
    print('Connection Successful to PSQL')
except: 
    print('Unable to Connect')
# Out:
# Connection Successful to PSQL

# %%
data.columns= data.columns.str.lower()

# %%
data.columns
# Out:
# Index(['invoice_id', 'branch', 'city', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin', 'total'],
#       dtype='object')

# %%
data.to_sql(name = 'walmart', con = engine_psql, if_exists ='append', index = False)
# Out:
# 969
